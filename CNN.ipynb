# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch import optim
from torch import nn
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.quantization import QuantStub, DeQuantStub

# %%
class CNN(nn.Module):
    def __init__(self, in_channels=1, num_classes=10):
        """
        Define the layers of the convolutional neural network.

        Parameters:
            in_channels: int
                The number of channels in the input image. For MNIST, this is 1 (grayscale images).
            num_classes: int
                The number of classes we want to predict, in our case 10 (digits 0 to 9).
        """
        super(CNN, self).__init__()

        self.quant = QuantStub()    # Converts FP32 to INT8
        # First convolutional layer: 1 input channel, 8 output channels, 3x3 kernel, stride 1, padding 1
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=8, kernel_size=3, stride=1, padding=1)

        self.relu1 = nn.ReLU()
        # Max pooling layer: 2x2 window, stride 2
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        # Second convolutional layer: 8 input channels, 16 output channels, 3x3 kernel, stride 1, padding 1
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)

        self.relu2 = nn.ReLU()
        # Fully connected layer: 16*7*7 input features (after two 2x2 poolings), 10 output features (num_classes)
        self.fc1 = nn.Linear(16 * 7 * 7, num_classes)

        self.dequant = DeQuantStub()

    def forward(self, x):
        """
        Define the forward pass of the neural network.

        Parameters:
            x: torch.Tensor
                The input tensor.

        Returns:
            torch.Tensor
                The output tensor after passing through the network.
        """
        x = self.quant(x)
        x = self.relu1(self.conv1(x))  # Apply first convolution and ReLU activation
        x = self.pool(x)           # Apply max pooling
        x = self.relu2(self.conv2(x))  # Apply second convolution and ReLU activation
        x = self.pool(x)           # Apply max pooling
        x = x.reshape(x.shape[0], -1)  # Flatten the tensor
        x = self.fc1(x)            # Apply fully connected layer
        x = self.dequant(x)
        return x

# %%
input_size = 784  # 28x28 pixels (not directly used in CNN)
num_classes = 10  # digits 0-9
learning_rate = 0.001
batch_size = 64
num_epochs = 10  # Reduced for demonstration purposes

# %%
train_dataset = datasets.MNIST(root="dataset/", download=True, train=True, transform=transforms.ToTensor())
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = datasets.MNIST(root="dataset/", download=True, train=False, transform=transforms.ToTensor())
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model = CNN(in_channels=1, num_classes=num_classes).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    print(f"Epoch [{epoch + 1}/{num_epochs}]")
    for batch_index, (data, targets) in enumerate(tqdm(train_loader)):
        # Move data and targets to the device (GPU/CPU)
        data = data.to(device)
        targets = targets.to(device)

        # Forward pass: compute the model output
        scores = model(data)
        loss = criterion(scores, targets)

        # Backward pass: compute the gradients
        optimizer.zero_grad()
        loss.backward()

        # Optimization step: update the model parameters
        optimizer.step()
# Out:
# Epoch [1/10]
# 100%|██████████| 938/938 [00:27<00:00, 34.40it/s]
# Epoch [2/10]
# 100%|██████████| 938/938 [00:22<00:00, 41.66it/s]
# Epoch [3/10]
# 100%|██████████| 938/938 [00:21<00:00, 43.98it/s]
# Epoch [4/10]
# 100%|██████████| 938/938 [00:22<00:00, 42.47it/s]
# Epoch [5/10]
# 100%|██████████| 938/938 [00:22<00:00, 42.62it/s]
# Epoch [6/10]
# 100%|██████████| 938/938 [00:21<00:00, 44.20it/s]
# Epoch [7/10]
# 100%|██████████| 938/938 [00:21<00:00, 42.89it/s]
# Epoch [8/10]
# 100%|██████████| 938/938 [00:22<00:00, 42.55it/s]
# Epoch [9/10]
# 100%|██████████| 938/938 [00:22<00:00, 42.54it/s]
# Epoch [10/10]
# 100%|██████████| 938/938 [00:21<00:00, 44.07it/s]

# %%
def check_accuracy(loader, model):
    """
    Checks the accuracy of the model on the given dataset loader.

    Parameters:
        loader: DataLoader
            The DataLoader for the dataset to check accuracy on.
        model: nn.Module
            The neural network model.
    """
    if loader.dataset.train:
        print("Checking accuracy on training data")
    else:
        print("Checking accuracy on test data")

    num_correct = 0
    num_samples = 0
    model.eval()  # Set the model to evaluation mode

    with torch.no_grad():  # Disable gradient calculation
        for x, y in loader:
            x = x.to(device)
            y = y.to(device)

            # Forward pass: compute the model output
            scores = model(x)
            _, predictions = scores.max(1)  # Get the index of the max log-probability
            num_correct += (predictions == y).sum()  # Count correct predictions
            num_samples += predictions.size(0)  # Count total samples

        # Calculate accuracy
        accuracy = float(num_correct) / float(num_samples) * 100
        print(f"Got {num_correct}/{num_samples} with accuracy {accuracy:.2f}%")

    model.train()  # Set the model back to training mode

# Final accuracy check on training and test sets
check_accuracy(train_loader, model)
check_accuracy(test_loader, model)
# Out:
# Checking accuracy on training data
# Got 59561/60000 with accuracy 99.27%
# Checking accuracy on test data
# Got 9887/10000 with accuracy 98.87%

# %%
torch.save(model.state_dict(), "model_fp32.pth")
print("Phase 1: FP32 Training Complete & Saved.")
# Out:
# Phase 1: FP32 Training Complete & Saved.

# %% [markdown]
# # Quantization

# %%
# 1. Initialize and Load
model = CNN(in_channels=1, num_classes=10).to('cpu')
# CRITICAL: Load your trained weights from your saved file
model.load_state_dict(torch.load('model_fp32.pth', map_location='cpu'))
model.eval()

# 2. Check FP32 Accuracy FIRST
# If this isn't 90%+, don't bother quantizing yet!
print("Verifying loaded FP32 model...")
check_accuracy(test_loader, model)

# 3. Prepare for Static PTQ
model.qconfig = torch.quantization.get_default_qconfig('fbgemm')
model_fused = torch.quantization.fuse_modules(model, [['conv1', 'relu1'], ['conv2', 'relu2']])
model_prepared = torch.quantization.prepare(model_fused)

# 4. Calibrate (Use real data!)
with torch.no_grad():
    for images, _ in test_loader:
        model_prepared(images) # This fills the stubs with range data

# 5. Convert
model_int8 = torch.quantization.convert(model_prepared)

# 6. Check INT8 Accuracy
print("Verifying INT8 model...")
check_accuracy(test_loader, model_int8)
# Out:
# Verifying loaded FP32 model...
# Checking accuracy on test data
# Got 9887/10000 with accuracy 98.87%
# /tmp/ipykernel_907/3185919303.py:15: DeprecationWarning: torch.ao.quantization is deprecated and will be removed in 2.10.
# For migrations of users:
# 1. Eager mode quantization (torch.ao.quantization.quantize, torch.ao.quantization.quantize_dynamic), please migrate to use torchao eager mode quantize_ API instead
# 2. FX graph mode quantization (torch.ao.quantization.quantize_fx.prepare_fx,torch.ao.quantization.quantize_fx.convert_fx, please migrate to use torchao pt2e quantization API instead (prepare_pt2e, convert_pt2e)
# 3. pt2e quantization has been migrated to torchao (https://github.com/pytorch/ao/tree/main/torchao/quantization/pt2e)
# see https://github.com/pytorch/ao/issues/2259 for more details
#   model_prepared = torch.quantization.prepare(model_fused)
# ...

# %%
import time

# --- BENCHMARKING FUNCTION ---
def benchmark_model(model, loader, model_name="Model"):
    model.eval()
    model.to('cpu')  # Ensure CPU execution for both

    num_correct = 0
    num_samples = 0
    latencies = []

    with torch.no_grad():
        for x, y in loader:
            # We measure time for each batch and average it per-image
            start_time = time.perf_counter()
            scores = model(x)
            end_time = time.perf_counter()

            # Record latency for this batch
            batch_latency = (end_time - start_time) / x.size(0) * 1000 # ms per image
            latencies.append(batch_latency)

            # Accuracy calculation
            _, predictions = scores.max(1)
            num_correct += (predictions == y).sum().item()
            num_samples += predictions.size(0)

    avg_acc = (num_correct / num_samples) * 100
    avg_latency = sum(latencies) / len(latencies)

    print(f"--- {model_name} Results ---")
    print(f"Accuracy: {avg_acc:.2f}%")
    print(f"Latency:  {avg_latency:.4f} ms per image")
    return avg_acc, avg_latency

# --- RUNNING THE COMPARISON ---

# 1. Benchmark original FP32 model
# Note: Use a smaller subset of test_loader if it's too slow
fp32_acc, fp32_lat = benchmark_model(model, test_loader, "FP32 (Original)")

# 2. Benchmark INT8 model
int8_acc, int8_lat = benchmark_model(model_int8, test_loader, "INT8 (Quantized)")

# --- SUMMARY ---
print("\n" + "="*30)
print("FINAL COMPARISON")
print("="*30)
print(f"Speedup: {fp32_lat / int8_lat:.2f}x faster")
print(f"Accuracy Change: {int8_acc - fp32_acc:.2f}%")
# Out:
# --- FP32 (Original) Results ---
# Accuracy: 98.87%
# Latency:  0.1043 ms per image
# --- INT8 (Quantized) Results ---
# Accuracy: 98.78%
# Latency:  0.1811 ms per image
#
# ...
# FINAL COMPARISON
# ...
# Speedup: 0.58x faster
# Accuracy Change: -0.09%

# %% [markdown]
# # Exporting Weights

# %%
import numpy as np

def simulate_hls_fixed_point(float_val, total_bits, int_bits):
    frac_bits = total_bits - int_bits
    scaling = 2**frac_bits
    # Simulate the quantization and clipping of HLS
    step = 1.0 / scaling
    quantized = np.round(float_val / step) * step
    return quantized

# Test a weight from your model
sample_weight = 0.321
hls_style = simulate_hls_fixed_point(sample_weight, 8, 3)
print(f"Original: {sample_weight} -> HLS <8,5>: {hls_style}")
# If 0.321 becomes 0.25 or 0.375, you can see the error immediately.
# Out:
# Original: 0.321 -> HLS <8,5>: 0.3125

# %%
import matplotlib.pyplot as plt

def simulate_ap_fixed(data, total_bits, int_bits):
    """Simulates HLS ap_fixed quantization and clipping."""
    frac_bits = total_bits - int_bits
    step = 2.0 ** -frac_bits
    min_val = -(2.0 ** (int_bits - 1))
    max_val = (2.0 ** (int_bits - 1)) - step

    quantized_data = np.round(data / step) * step
    return np.clip(quantized_data, min_val, max_val)

def export_and_verify_data(loader, num_images=50, total_bits=8, int_bits=5):
    # 1. Collect exactly 50 pairs
    synced_images = []
    synced_labels = []

    # We use a fresh iterator to avoid shuffle issues
    data_iter = iter(loader)
    images, labels = next(data_iter)

    print(f"Quantizing images to ap_fixed<{total_bits}, {int_bits}>...")

    for i in range(num_images):
        # Flatten (1, 28, 28) -> (784,)
        img_np = images[i].numpy().flatten()

        # --- APPLY FPGA QUANTIZATION TO PIXELS ---
        img_quantized = simulate_ap_fixed(img_np, total_bits, int_bits)

        label_np = labels[i].item()

        synced_images.append(img_quantized)
        synced_labels.append(label_np)

    # --- 2. MANUAL VERIFICATION PLOT ---
    print("Verifying the 50 quantized images in the export batch:")
    plt.figure(figsize=(15, 6)) # Adjusted slightly so it renders well in Colab
    for i in range(50):
        # 5 rows, 10 columns for 50 images
        plt.subplot(5, 10, i+1)
        # Reshape the quantized flattened array back to 28x28 for the plot
        plt.imshow(synced_images[i].reshape(28, 28), cmap='gray')
        plt.title(f"{synced_labels[i]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

    # --- 3. WRITE TO HEADERS ---
    # Images
    all_imgs = np.concatenate(synced_images)
    with open("mnist_data.h", "w") as f:
        f.write("#ifndef MNIST_DATA_H\n#define MNIST_DATA_H\n#include <ap_fixed.h>\n")
        # Dynamically write the typedef
        f.write(f"typedef ap_fixed<{total_bits}, {int_bits}> fixed;\n\n")
        f.write(f"fixed mnist_images[{len(all_imgs)}] = {{\n  ")
        for i, val in enumerate(all_imgs):
            # Write 6 decimal places to ensure precision for ap_fixed
            f.write(f"{val:.6f}")
            if i < len(all_imgs)-1: f.write(", ")
            if (i+1) % 28 == 0: f.write("\n  ")
        f.write("\n};\n#endif")

    # Labels
    with open("labels.h", "w") as f:
        f.write("#ifndef LABELS_H\n#define LABELS_H\n\n")
        f.write(f"int labels[{len(synced_labels)}] = {{\n  ")
        for i, val in enumerate(synced_labels):
            f.write(str(val))
            if i < len(synced_labels)-1: f.write(", ")
        f.write("\n};\n#endif")

    print(f"\nSUCCESS: Exported {num_images} images and labels for <{total_bits}, {int_bits}>.")
    return synced_images, synced_labels

# Set your precision here to match your weights!
W = 8
I = 3
exp_imgs, exp_lbls = export_and_verify_data(test_loader, num_images=50, total_bits=W, int_bits=I)
# Out:
# Quantizing images to ap_fixed<8, 3>...
# Verifying the 50 quantized images in the export batch:
# SUCCESS: Exported 50 images and labels for <8, 3>.

# %%
def simulate_ap_fixed(data, total_bits, int_bits):
    """
    Simulates HLS ap_fixed quantization and overflow/clipping.
    """
    frac_bits = total_bits - int_bits
    step = 2.0 ** -frac_bits

    # Calculate Two's Complement Range
    # e.g., int_bits=5 means 1 sign bit + 4 integer bits = [-16.0 to 15.875]
    min_val = -(2.0 ** (int_bits - 1))
    max_val = (2.0 ** (int_bits - 1)) - step

    # 1. Simulate Precision Loss (Rounding to nearest step)
    quantized_data = np.round(data / step) * step

    # 2. Simulate Overflow (Clipping to max/min range)
    clipped_data = np.clip(quantized_data, min_val, max_val)

    return clipped_data

def export_to_hls_header(name, tensor, filename, total_bits=8, int_bits=5):
    # 1. Handle the 'function' vs 'tensor' issue
    if callable(tensor):
        t = tensor()
    else:
        t = tensor

    # 2. Extract data safely with contiguous memory layout
    if t.is_quantized:
        data = t.dequantize().detach().cpu().contiguous().numpy().flatten()
    else:
        data = t.detach().cpu().contiguous().numpy().flatten()

    # --- 3. APPLY FPGA QUANTIZATION ---
    data_fixed = simulate_ap_fixed(data, total_bits, int_bits)

    # Check if we are destroying the data
    mse = np.mean((data - data_fixed)**2)
    if mse > 0.05:
        print(f"  [!] Warning: High quantization loss (MSE={mse:.4f}) for {name}")

    var_name = name.replace(".", "_")
    size = data_fixed.size

    # 4. Write to Header
    with open(filename, 'w') as f:
        f.write(f"#ifndef {var_name.upper()}_H\n")
        f.write(f"#define {var_name.upper()}_H\n\n")
        f.write("#include <ap_fixed.h>\n")
        # Dynamically write the typedef!
        f.write(f"typedef ap_fixed<{total_bits}, {int_bits}> fixed;\n\n")
        f.write(f"fixed {var_name}[{size}] = {{\n  ")

        for i, val in enumerate(data_fixed):
            f.write(f"{val:.6f}")
            if i < size - 1:
                f.write(", ")
            if (i + 1) % 8 == 0:
                f.write("\n  ")

        f.write("\n};\n\n")
        f.write(f"#endif // {var_name.upper()}_H\n")
    print(f"Exported {filename} formatted for <{total_bits}, {int_bits}>")


# --- Export Loop ---
layers_to_export = ['conv1', 'conv2', 'fc1']

# Set your target precision here!
W = 8 # Total bits
I = 3 # Integer bits (Try 3, 4, 5, or 6 to see what happens!)

print(f"--- Exporting model to ap_fixed<{W}, {I}> ---")

for name, module in model_int8.named_modules():
    if any(base == name for base in layers_to_export):

        # Export Weights
        if hasattr(module, 'weight'):
            export_to_hls_header(f"{name}_weight", module.weight, f"{name}_weight.h", total_bits=W, int_bits=I)

        # Export Biases
        if hasattr(module, 'bias') and module.bias() is not None:
            export_to_hls_header(f"{name}_bias", module.bias, f"{name}_bias.h", total_bits=W, int_bits=I)
# Out:
# --- Exporting model to ap_fixed<8, 3> ---
# Exported conv1_weight.h formatted for <8, 3>
# Exported conv1_bias.h formatted for <8, 3>
# Exported conv2_weight.h formatted for <8, 3>
# Exported conv2_bias.h formatted for <8, 3>
# Exported fc1_weight.h formatted for <8, 3>
# Exported fc1_bias.h formatted for <8, 3>
